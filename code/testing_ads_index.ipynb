# %%
import pandas as pd
import numpy as np

# %%
ads_index = pd.read_csv("./data/ads_data_index.csv")

# %%
ads_index
# Out:
#      count                       groupMetadataID    start_time      end_time  \
# 0        1  3a116996-93a9-11ee-956e-9da2d070324c  1.674160e+18  1.674160e+18
# 1        2  2837eb9c-9542-11ee-956e-9da2d070324c  1.683310e+18  1.683320e+18
# 2        3  da853e0c-a10f-11ee-981c-d126ddbe9afa  1.684780e+18  1.684780e+18
# 3        4  154fab12-a43f-11ee-88ec-eb6a8d5269b4  1.684780e+18  1.684780e+18
# 4        7  ba6e1072-9524-11ee-956e-9da2d070324c  1.685540e+18  1.685540e+18
# ..     ...                                   ...           ...           ...
# 325    199  f8fd0fd8-f243-11ee-bb3f-fb353e7798cd  1.701200e+18  1.701200e+18
# 326    200  58d78342-f24a-11ee-bb45-fb353e7798cd  1.701200e+18  1.701200e+18
# 327    201  25135418-f250-11ee-bb4a-fb353e7798cd  1.701200e+18  1.701200e+18
# 328    202  cbdc93f4-f255-11ee-bb4e-fb353e7798cd  1.701200e+18  1.701200e+18
# 329    203  de226278-f25a-11ee-bb4e-fb353e7798cd  1.701200e+18  1.701210e+18
#
#      nummsgs                                           filebase  \
# 0    1855470  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 1    1149980  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 2     459295  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 3     559423  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 4     463801  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# ..       ...                                                ...
# 325   758506  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...
# 326   727298  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...
# 327   751183  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...
# 328   705558  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...
# 329   743008  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...
#
#                                                 folder   vehilceID  \
# 0    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 1    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 2    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 3    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 4    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# ..                                                 ...         ...
# 325  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...        Van2
# 326  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...        Van2
# 327  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...        Van2
# 328  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...        Van2
# 329  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...        Van2
#
#      experimentID
# 0              13
# 1               1
# 2               2
# 3               3
# 4               4
# ..            ...
# 325    1701196779
# 326    1701198151
# 327    1701199673
# 328    1701203037
# 329    1701204159
#
# [330 rows x 9 columns]

# %% [markdown]
# ## Cleaning and calculations

# %%
if "vehilceID" in ads_index.columns:
    ads_index.rename({'vehilceID': 'vehicleID'}, axis=1, inplace=True)


# ads_index['duration'] = ads_index['end_time'] - ads_index['start_time']

# %% [markdown]
# ## Route Analysis

# %% [markdown]
# example split of a string to extract route color

# %%
s = '/Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/20230119141333.record.00000'

s.split("/")[2]
# Out:
# 'Blue Route'

# %%
routes = ads_index["filebase"].copy().apply(lambda s: s.split("/")[2])
ads_index["route"] = routes
ads_index
# Out:
#      count                       groupMetadataID    start_time      end_time  \
# 0        1  3a116996-93a9-11ee-956e-9da2d070324c  1.674160e+18  1.674160e+18
# 1        2  2837eb9c-9542-11ee-956e-9da2d070324c  1.683310e+18  1.683320e+18
# 2        3  da853e0c-a10f-11ee-981c-d126ddbe9afa  1.684780e+18  1.684780e+18
# 3        4  154fab12-a43f-11ee-88ec-eb6a8d5269b4  1.684780e+18  1.684780e+18
# 4        7  ba6e1072-9524-11ee-956e-9da2d070324c  1.685540e+18  1.685540e+18
# ..     ...                                   ...           ...           ...
# 325    199  f8fd0fd8-f243-11ee-bb3f-fb353e7798cd  1.701200e+18  1.701200e+18
# 326    200  58d78342-f24a-11ee-bb45-fb353e7798cd  1.701200e+18  1.701200e+18
# 327    201  25135418-f250-11ee-bb4a-fb353e7798cd  1.701200e+18  1.701200e+18
# 328    202  cbdc93f4-f255-11ee-bb4e-fb353e7798cd  1.701200e+18  1.701200e+18
# 329    203  de226278-f25a-11ee-bb4e-fb353e7798cd  1.701200e+18  1.701210e+18
#
#      nummsgs                                           filebase  \
# 0    1855470  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 1    1149980  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 2     459295  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 3     559423  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 4     463801  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# ..       ...                                                ...
# 325   758506  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...
# 326   727298  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...
# 327   751183  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...
# 328   705558  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...
# 329   743008  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...
#
#                                                 folder   vehicleID  \
# 0    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 1    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 2    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 3    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 4    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# ..                                                 ...         ...
# 325  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...        Van2
# 326  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...        Van2
# 327  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...        Van2
# 328  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...        Van2
# 329  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...        Van2
#
#      experimentID       route
# 0              13  Blue Route
# 1               1  Blue Route
# 2               2  Blue Route
# 3               3  Blue Route
# 4               4  Blue Route
# ..            ...         ...
# 325    1701196779  GreenRoute
# 326    1701198151  GreenRoute
# 327    1701199673  GreenRoute
# 328    1701203037  GreenRoute
# 329    1701204159  GreenRoute
#
# [330 rows x 10 columns]

# %%
ads_index["route"].value_counts()
# Out:
# route
# Blue Route    120
# GreenRoute    109
# RedRoute      101
# Name: count, dtype: int64

# %% [markdown]
# ## Vehicle Analysis

# %%
ads_index["vehicleID"].value_counts()
# Out:
# vehicleID
# Van1          245
# Van2           44
# OUPacifica     41
# Name: count, dtype: int64

# %%
d = pd.DataFrame(ads_index[["vehicleID", "route"]].value_counts(sort=False))
d['proportion'] = ads_index[["vehicleID", "route"]].value_counts(sort=False, normalize=True) * 100


d
# Out:
#                        count  proportion
# vehicleID  route
# OUPacifica Blue Route     20    6.060606
#            GreenRoute     11    3.333333
#            RedRoute       10    3.030303
# Van1       Blue Route     84   25.454545
#            GreenRoute     76   23.030303
#            RedRoute       85   25.757576
# Van2       Blue Route     16    4.848485
#            GreenRoute     22    6.666667
#            RedRoute        6    1.818182

# %%
e = pd.DataFrame(ads_index[["route", "vehicleID"]].value_counts(sort=False))

e['proportion'] = ads_index[["route", "vehicleID"]].value_counts(sort=False, normalize=True) * 100

e
# Out:
#                        count  proportion
# route      vehicleID
# Blue Route OUPacifica     20    6.060606
#            Van1           84   25.454545
#            Van2           16    4.848485
# GreenRoute OUPacifica     11    3.333333
#            Van1           76   23.030303
#            Van2           22    6.666667
# RedRoute   OUPacifica     10    3.030303
#            Van1           85   25.757576
#            Van2            6    1.818182

# %%
ads_index[ads_index['route'] == 'RedRoute'].sort_values(by='experimentID')
# Out:
#      count                       groupMetadataID    start_time      end_time  \
# 5       11  1bbbfbae-c839-11ee-a7fc-dd032dba19e8  1.686170e+18  1.686170e+18
# 8       80  6d2ea45a-c839-11ee-a7fc-dd032dba19e8  1.694620e+18  1.694630e+18
# 11      90  8fa6fe80-c869-11ee-a7fc-dd032dba19e8  1.695230e+18  1.695230e+18
# 13      96  7fb7b9c0-c881-11ee-a7fc-dd032dba19e8  1.695840e+18  1.695840e+18
# 17     109  51ef6da6-ca9f-11ee-909c-e1dc60cf66f9  1.696440e+18  1.696440e+18
# ..     ...                                   ...           ...           ...
# 266    310  662741a4-f38a-11ee-bb4e-fb353e7798cd  1.707420e+18  1.707420e+18
# 267    311  65cfbfd6-f396-11ee-bb4e-fb353e7798cd  1.708010e+18  1.708010e+18
# 268    312  c25271be-f3a4-11ee-bb4e-fb353e7798cd  1.708020e+18  1.708020e+18
# 269    313  868de15e-f3b3-11ee-bb4e-fb353e7798cd  1.708030e+18  1.708030e+18
# 281    325  3344a3c0-f502-11ee-8afa-cb629b0d53e6  1.708630e+18  1.708630e+18
#
#      nummsgs                                           filebase  \
# 5     160256  /Deployment_2_SEOhio/RedRoute/OU Pacifica/1686...
# 8    1816742  /Deployment_2_SEOhio/RedRoute/OU Pacifica/1694...
# 11   2002226  /Deployment_2_SEOhio/RedRoute/OU Pacifica/1695...
# 13   1892364  /Deployment_2_SEOhio/RedRoute/OU Pacifica/1695...
# 17   1753843  /Deployment_2_SEOhio/RedRoute/OU Pacifica/1696...
# ..       ...                                                ...
# 266  1435965  /Deployment_2_SEOhio/RedRoute/TRCVan1/17074220...
# 267  1638330  /Deployment_2_SEOhio/RedRoute/TRCVan1/17080115...
# 268  1692068  /Deployment_2_SEOhio/RedRoute/TRCVan1/17080151...
# 269  1691034  /Deployment_2_SEOhio/RedRoute/TRCVan1/17080246...
# 281  1633989  /Deployment_2_SEOhio/RedRoute/TRCVan1/17086256...
#
#                                                 folder   vehicleID  \
# 5    /Deployment_2_SEOhio/RedRoute/OU Pacifica/1686...  OUPacifica
# 8    /Deployment_2_SEOhio/RedRoute/OU Pacifica/1694...  OUPacifica
# 11   /Deployment_2_SEOhio/RedRoute/OU Pacifica/1695...  OUPacifica
# 13   /Deployment_2_SEOhio/RedRoute/OU Pacifica/1695...  OUPacifica
# 17   /Deployment_2_SEOhio/RedRoute/OU Pacifica/1696...  OUPacifica
# ..                                                 ...         ...
# 266  /Deployment_2_SEOhio/RedRoute/TRCVan1/17074220...        Van1
# 267  /Deployment_2_SEOhio/RedRoute/TRCVan1/17080115...        Van1
# 268  /Deployment_2_SEOhio/RedRoute/TRCVan1/17080151...        Van1
# 269  /Deployment_2_SEOhio/RedRoute/TRCVan1/17080246...        Van1
# 281  /Deployment_2_SEOhio/RedRoute/TRCVan1/17086256...        Van1
#
#      experimentID     route
# 5               5  RedRoute
# 8              11  RedRoute
# 11             12  RedRoute
# 13             15  RedRoute
# 17             19  RedRoute
# ..            ...       ...
# 266    1707422085  RedRoute
# 267    1708011504  RedRoute
# 268    1708015127  RedRoute
# 269    1708024622  RedRoute
# 281    1708625632  RedRoute
#
# [101 rows x 10 columns]

# %%
import os


red_IDs = ads_index[ads_index['route'] == 'RedRoute']['groupMetadataID'].tolist()

ids = []

red_IDs

for id in red_IDs:
    if f'{id}' in os.listdir('./data/Raw_Data'):
        ids.append(id)

ids
# Out:
# ['1bbbfbae-c839-11ee-a7fc-dd032dba19e8',
#  '6d2ea45a-c839-11ee-a7fc-dd032dba19e8',
#  '8fa6fe80-c869-11ee-a7fc-dd032dba19e8',
#  '7fb7b9c0-c881-11ee-a7fc-dd032dba19e8',
#  '51ef6da6-ca9f-11ee-909c-e1dc60cf66f9',
#  '8437f77a-cab7-11ee-909c-e1dc60cf66f9',
#  '853ef120-cad3-11ee-909c-e1dc60cf66f9',
#  'd12cd1c4-caec-11ee-909c-e1dc60cf66f9',
#  'c338788a-d324-11ee-b437-336917683bb8',
#  'c9c6856c-d33c-11ee-b437-336917683bb8',
#  '05c7c824-cab8-11ee-aa4d-1d66adf2f0c7',
#  '2462c9d0-eecd-11ee-9385-ef789ffde1d3',
#  '94c53148-eeed-11ee-9385-ef789ffde1d3',
#  '88a68dd8-eef9-11ee-9385-ef789ffde1d3',
#  '4ed017ee-ef05-11ee-9385-ef789ffde1d3',
#  'aa5dbcd2-ef10-11ee-9385-ef789ffde1d3',
#  'e7b934a8-ef1a-11ee-9385-ef789ffde1d3',
#  '85b6e70e-ef7a-11ee-b966-fb353e7798cd',
#  '219f7eb8-ef87-11ee-b966-fb353e7798cd',
#  '3d2d29ec-ef95-11ee-b966-fb353e7798cd',
#  'd3698592-ef9d-11ee-b966-fb353e7798cd',
#  'fd1ab258-efa7-11ee-b966-fb353e7798cd',
#  '8347b862-efad-11ee-b966-fb353e7798cd',
#  '817d6848-efb6-11ee-b966-fb353e7798cd',
#  'be857244-efc0-11ee-b966-fb353e7798cd',
#  'fc211bb2-efca-11ee-b966-fb353e7798cd',
#  '01e65360-efd4-11ee-b966-fb353e7798cd',
#  '1b6aca0e-efdf-11ee-b966-fb353e7798cd',
#  '72a03d4a-efe9-11ee-b966-fb353e7798cd',
#  '3151e9e2-eff3-11ee-b966-fb353e7798cd',
#  'f41cbd44-eff8-11ee-b966-fb353e7798cd',
#  '5a4bccf4-effe-11ee-b966-fb353e7798cd',
#  '2f95c748-f009-11ee-b966-fb353e7798cd',
#  'fcc6fcd2-f013-11ee-b966-fb353e7798cd',
#  'f43b6a70-f01e-11ee-b966-fb353e7798cd',
#  '457dc5ee-f02a-11ee-b966-fb353e7798cd',
#  '787f70da-f036-11ee-b966-fb353e7798cd',
#  '6daff50c-f041-11ee-b972-fb353e7798cd',
#  '23a7aa3e-f048-11ee-b97d-fb353e7798cd',
#  'ef63db62-f051-11ee-b986-fb353e7798cd',
#  '48021fe0-f05c-11ee-b992-fb353e7798cd',
#  'bb52690a-f066-11ee-b99e-fb353e7798cd',
#  '599673dc-f070-11ee-b9a9-fb353e7798cd',
#  '26af7004-f07a-11ee-b9b2-fb353e7798cd',
#  '5230b9be-f083-11ee-b9b8-fb353e7798cd',
#  '4bbe3c64-f088-11ee-b9c3-fb353e7798cd',
#  '5c2ad8ec-f08c-11ee-b9c8-fb353e7798cd',
#  '6c5f7416-f096-11ee-b9d4-fb353e7798cd',
#  'ede139be-f098-11ee-b9d8-fb353e7798cd',
#  'dbff355c-f0a2-11ee-b9e3-fb353e7798cd',
#  'eb22edf4-f0ab-11ee-b9e9-fb353e7798cd',
#  'd1d69a76-f0b5-11ee-b9f0-fb353e7798cd',
#  '906d3c4e-f0be-11ee-b9fb-fb353e7798cd',
#  '2bb03aaa-f0c7-11ee-ba06-fb353e7798cd',
#  'dd72fdec-f0cf-11ee-ba0d-fb353e7798cd',
#  '211bdb36-f0da-11ee-ba1b-fb353e7798cd',
#  'f0eebb6a-f0dc-11ee-ba1e-fb353e7798cd',
#  '1f70a4f0-f0e0-11ee-ba1e-fb353e7798cd',
#  'f711e68e-f0e1-11ee-ba1f-fb353e7798cd',
#  '622bd2e8-f0e4-11ee-ba1f-fb353e7798cd',
#  '7d27535e-f0e6-11ee-ba21-fb353e7798cd',
#  '8dbbbf1c-f0ef-11ee-ba29-fb353e7798cd',
#  'd21965e6-f0fa-11ee-ba37-fb353e7798cd',
#  '171c50bc-f106-11ee-ba42-fb353e7798cd',
#  'de933de8-f112-11ee-ba4d-fb353e7798cd',
#  '9189a2a8-f121-11ee-ba5b-fb353e7798cd',
#  'f755cf60-f132-11ee-ba6d-fb353e7798cd',
#  '9798fe24-f143-11ee-ba78-fb353e7798cd',
#  '35518ec4-f153-11ee-ba88-fb353e7798cd',
#  'ecebb942-f162-11ee-ba97-fb353e7798cd',
#  '1ee938a2-f172-11ee-baa6-fb353e7798cd',
#  '38ac9526-f182-11ee-bab0-fb353e7798cd',
#  '6f5b3612-f18d-11ee-bab8-fb353e7798cd',
#  'd24820c8-f197-11ee-babe-fb353e7798cd',
#  'bf518644-f1a6-11ee-bac9-fb353e7798cd',
#  '3950298e-f1b4-11ee-bad3-fb353e7798cd',
#  'cccc7d32-f1c0-11ee-bada-fb353e7798cd',
#  'a6895b74-f1cd-11ee-bae2-fb353e7798cd',
#  '61b4e416-f1da-11ee-bae8-fb353e7798cd',
#  'fc1e1b6a-f1e6-11ee-baf6-fb353e7798cd',
#  'b82476fe-f1f3-11ee-baff-fb353e7798cd',
#  '286e019a-f204-11ee-bb07-fb353e7798cd',
#  '84d96f18-f214-11ee-bb13-fb353e7798cd',
#  '88dd6fbe-f224-11ee-bb21-fb353e7798cd',
#  '61b12e7a-f234-11ee-bb33-fb353e7798cd',
#  '7cbd932e-f244-11ee-bb3f-fb353e7798cd',
#  'cf831f42-f353-11ee-bb4e-fb353e7798cd',
#  '43a1a35e-f362-11ee-bb4e-fb353e7798cd',
#  'bfde2aec-f370-11ee-bb4e-fb353e7798cd',
#  '0b72a836-f37e-11ee-bb4e-fb353e7798cd',
#  '662741a4-f38a-11ee-bb4e-fb353e7798cd',
#  '65cfbfd6-f396-11ee-bb4e-fb353e7798cd',
#  'c25271be-f3a4-11ee-bb4e-fb353e7798cd',
#  '868de15e-f3b3-11ee-bb4e-fb353e7798cd',
#  '3344a3c0-f502-11ee-8afa-cb629b0d53e6',
#  'c0555ef0-f50f-11ee-8afa-cb629b0d53e6',
#  'ce6465b6-f51b-11ee-8afa-cb629b0d53e6',
#  '2a61b8a8-f528-11ee-8afa-cb629b0d53e6',
#  '41b67a28-f52f-11ee-8afa-cb629b0d53e6',
#  'fe973c9c-f53c-11ee-8afa-cb629b0d53e6',
#  '96f7a614-f549-11ee-8afa-cb629b0d53e6']

# %% [markdown]
# ## Choosing a Red Route gmID

# %%
gmID = "1bbbfbae-c839-11ee-a7fc-dd032dba19e8"

df_chassis = pd.read_csv(f'./data/chassis/{gmID}.csv')
df_pose = pd.read_csv(f'./data/best_pose/{gmID}.csv')
df_metadata = pd.read_csv(f'./data/metadata/{gmID}.csv')
index_data = ads_index[ads_index['groupMetadataID'] == gmID].copy()

df_chassis.sort_values(by='time', inplace=True)
df_pose.sort_values(by='time', inplace=True)

# %%
df_chassis.head()

# %%
df_pose.head()

# %%
df_metadata.head()

# %%
index_data
