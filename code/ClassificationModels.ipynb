# %%
import pandas as pd
import numpy as np

import CalculatedFieldSubroutines as routines

# %%
ads_index = pd.read_csv("./data/ads_data_index.csv")

# %%
ads_index
# Out:
#      count                       groupMetadataID    start_time      end_time  \
# 0        1  3a116996-93a9-11ee-956e-9da2d070324c  1.674160e+18  1.674160e+18
# 1        2  2837eb9c-9542-11ee-956e-9da2d070324c  1.683310e+18  1.683320e+18
# 2        3  da853e0c-a10f-11ee-981c-d126ddbe9afa  1.684780e+18  1.684780e+18
# 3        4  154fab12-a43f-11ee-88ec-eb6a8d5269b4  1.684780e+18  1.684780e+18
# 4        7  ba6e1072-9524-11ee-956e-9da2d070324c  1.685540e+18  1.685540e+18
# ..     ...                                   ...           ...           ...
# 325    199  f8fd0fd8-f243-11ee-bb3f-fb353e7798cd  1.701200e+18  1.701200e+18
# 326    200  58d78342-f24a-11ee-bb45-fb353e7798cd  1.701200e+18  1.701200e+18
# 327    201  25135418-f250-11ee-bb4a-fb353e7798cd  1.701200e+18  1.701200e+18
# 328    202  cbdc93f4-f255-11ee-bb4e-fb353e7798cd  1.701200e+18  1.701200e+18
# 329    203  de226278-f25a-11ee-bb4e-fb353e7798cd  1.701200e+18  1.701210e+18
#
#      nummsgs                                           filebase  \
# 0    1855470  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 1    1149980  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 2     459295  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 3     559423  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 4     463801  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# ..       ...                                                ...
# 325   758506  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...
# 326   727298  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...
# 327   751183  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...
# 328   705558  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...
# 329   743008  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...
#
#                                                 folder   vehilceID  \
# 0    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 1    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 2    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 3    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 4    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# ..                                                 ...         ...
# 325  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...        Van2
# 326  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...        Van2
# 327  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...        Van2
# 328  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...        Van2
# 329  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...        Van2
#
#      experimentID
# 0              13
# 1               1
# 2               2
# 3               3
# 4               4
# ..            ...
# 325    1701196779
# 326    1701198151
# 327    1701199673
# 328    1701203037
# 329    1701204159
#
# [330 rows x 9 columns]

# %% [markdown]
# ## Cleaning and calculations

# %%
if "vehilceID" in ads_index.columns:
    ads_index.rename({'vehilceID': 'vehicleID'}, axis=1, inplace=True)


# ads_index['duration'] = ads_index['end_time'] - ads_index['start_time']

# %% [markdown]
# example split of a string to extract route color

# %%
s = '/Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/20230119141333.record.00000'

s.split("/")[2]
# Out:
# 'Blue Route'

# %%
routes = ads_index["filebase"].copy().apply(lambda s: s.split("/")[2])
ads_index["route"] = routes
ads_index
# Out:
#      count                       groupMetadataID    start_time      end_time  \
# 0        1  3a116996-93a9-11ee-956e-9da2d070324c  1.674160e+18  1.674160e+18
# 1        2  2837eb9c-9542-11ee-956e-9da2d070324c  1.683310e+18  1.683320e+18
# 2        3  da853e0c-a10f-11ee-981c-d126ddbe9afa  1.684780e+18  1.684780e+18
# 3        4  154fab12-a43f-11ee-88ec-eb6a8d5269b4  1.684780e+18  1.684780e+18
# 4        7  ba6e1072-9524-11ee-956e-9da2d070324c  1.685540e+18  1.685540e+18
# ..     ...                                   ...           ...           ...
# 325    199  f8fd0fd8-f243-11ee-bb3f-fb353e7798cd  1.701200e+18  1.701200e+18
# 326    200  58d78342-f24a-11ee-bb45-fb353e7798cd  1.701200e+18  1.701200e+18
# 327    201  25135418-f250-11ee-bb4a-fb353e7798cd  1.701200e+18  1.701200e+18
# 328    202  cbdc93f4-f255-11ee-bb4e-fb353e7798cd  1.701200e+18  1.701200e+18
# 329    203  de226278-f25a-11ee-bb4e-fb353e7798cd  1.701200e+18  1.701210e+18
#
#      nummsgs                                           filebase  \
# 0    1855470  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 1    1149980  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 2     459295  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 3     559423  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# 4     463801  /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...
# ..       ...                                                ...
# 325   758506  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...
# 326   727298  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...
# 327   751183  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...
# 328   705558  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...
# 329   743008  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...
#
#                                                 folder   vehicleID  \
# 0    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 1    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 2    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 3    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# 4    /Deployment_2_SEOhio/Blue Route/OU Pacifica/16...  OUPacifica
# ..                                                 ...         ...
# 325  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...        Van2
# 326  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...        Van2
# 327  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170119...        Van2
# 328  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...        Van2
# 329  /Deployment_2_SEOhio/GreenRoute/TRCVan2/170120...        Van2
#
#      experimentID       route
# 0              13  Blue Route
# 1               1  Blue Route
# 2               2  Blue Route
# 3               3  Blue Route
# 4               4  Blue Route
# ..            ...         ...
# 325    1701196779  GreenRoute
# 326    1701198151  GreenRoute
# 327    1701199673  GreenRoute
# 328    1701203037  GreenRoute
# 329    1701204159  GreenRoute
#
# [330 rows x 10 columns]

# %% [markdown]
# ## Reading data

# %%
blue_id  = ads_index[ads_index['route'] == 'Blue Route'].sort_values(by='experimentID')['groupMetadataID'].copy()

# %% [markdown]
# Just using a subset of blueroutes for now

# %%
route_count = blue_id.shape[0] // 3
print(route_count)
# Out:
# 40

# %%
import os

blue_df = pd.DataFrame()

for id in blue_id[:route_count]:
    print(id)
    
    temp_chassis = pd.read_csv(f'./data/Raw_Data/{id}/_apollo_canbus_chassis/{id}_apollo_canbus_chassis.csv')
    temp_best_pose = pd.read_csv(f'./data/Raw_Data/{id}/_apollo_sensor_gnss_best_pose/{id}_apollo_sensor_gnss_best_pose.csv')
    
    
    #if f'{id}' in os.listdir('./data/Raw_Data'):
    #    ids.append(id)
    
    
    #if f'{id}' in os.listdir('./data/Raw_Data'):
    #    ids.append(id)
    
    #temp_chassis['BinaryDrivingMode'] = np.where(temp_chassis['drivingMode'] == "COMPLETE_AUTO_DRIVE", 1, 0)
    routines.BinaryDrivingMode(temp_chassis)
    routines.TernaryDrivingModeTransition(temp_chassis)
    routines.LatLonTotalStdDev(temp_best_pose)
    
    
    routines.ChassisBestPoseMatchedTime(temp_chassis, temp_best_pose)
    
    temp_final = pd.merge(temp_chassis,temp_best_pose,on='ChassisBestPoseMatchedTime')
    
    blue_df= pd.concat([blue_df,temp_final])

blue_df
# Out:
# 2837eb9c-9542-11ee-956e-9da2d070324c
# da853e0c-a10f-11ee-981c-d126ddbe9afa
# 154fab12-a43f-11ee-88ec-eb6a8d5269b4
# ba6e1072-9524-11ee-956e-9da2d070324c
# 58263e34-a45c-11ee-88ec-eb6a8d5269b4
# c335d84c-a45c-11ee-88ec-eb6a8d5269b4
# 3a116996-93a9-11ee-956e-9da2d070324c
# f6ac3c82-a445-11ee-88ec-eb6a8d5269b4
# 5976b77a-a504-11ee-88ec-eb6a8d5269b4
# 2bc6ebb8-a529-11ee-88ec-eb6a8d5269b4
# 7f09f6c6-a5b0-11ee-88ec-eb6a8d5269b4
# f671c05c-a5e4-11ee-88ec-eb6a8d5269b4
# 90101c36-a621-11ee-88ec-eb6a8d5269b4
# 559495ca-d270-11ee-b437-336917683bb8
# feaf2ba8-d28d-11ee-b437-336917683bb8
# a253145a-d2a6-11ee-b437-336917683bb8
# 787d9684-d2c2-11ee-b437-336917683bb8
# 9830d896-d2dc-11ee-b437-336917683bb8
# 286c70cc-d2f7-11ee-b437-336917683bb8
# 64737d98-d312-11ee-b437-336917683bb8
# 88180f82-ed4f-11ee-9385-ef789ffde1d3
# baf0e4be-bede-11ee-835b-599066b5eb60
# 6af236d6-d98f-11ee-a158-97f8443fd730
# 39ba7438-d0d5-11ee-9435-f7e542e2436c
# c0624e24-d9aa-11ee-a158-97f8443fd730
# 19b7ebd0-d9b7-11ee-a158-97f8443fd730
# 47561998-d9c3-11ee-a158-97f8443fd730
# 59c189d8-ed54-11ee-9385-ef789ffde1d3
# d94ef300-ed60-11ee-9385-ef789ffde1d3
# 8b6a6cfc-ed6d-11ee-9385-ef789ffde1d3
# 530de03a-ed79-11ee-9385-ef789ffde1d3
# 43914d48-ed85-11ee-9385-ef789ffde1d3
# c9023e32-ed90-11ee-9385-ef789ffde1d3
# 86841630-d9d0-11ee-a158-97f8443fd730
# e269948a-ed9d-11ee-9385-ef789ffde1d3
# 60546ef4-edaa-11ee-9385-ef789ffde1d3
# 76683d3c-db18-11ee-a158-97f8443fd730
# 3a2a78cc-db21-11ee-a158-97f8443fd730
# f9d62032-db2a-11ee-a158-97f8443fd730
# dc39aa14-db32-11ee-a158-97f8443fd730
#        yawRate          drivingMode                 topic_x  msgsize_x  \
# 0            0      COMPLETE_MANUAL  /apollo/canbus/chassis        134
# 1            0      COMPLETE_MANUAL  /apollo/canbus/chassis        134
# 2            0      COMPLETE_MANUAL  /apollo/canbus/chassis        134
# 3            0      COMPLETE_MANUAL  /apollo/canbus/chassis        134
# 4            0      COMPLETE_MANUAL  /apollo/canbus/chassis        134
# ...        ...                  ...                     ...        ...
# 55891        0  COMPLETE_AUTO_DRIVE  /apollo/canbus/chassis        134
# 55892        0       EMERGENCY_MODE  /apollo/canbus/chassis        134
# 55893        0  COMPLETE_AUTO_DRIVE  /apollo/canbus/chassis        134
# 55894        0  COMPLETE_AUTO_DRIVE  /apollo/canbus/chassis        134
# 55895        0  COMPLETE_AUTO_DRIVE  /apollo/canbus/chassis        134
#
#                     time_x gearLocation                          metadataID_x  \
# 0      1683314959730769101   GEAR_DRIVE  58daaaec-a437-11ee-88ec-eb6a8d5269b4
# 1      1683315273890943328   GEAR_DRIVE  4a80a5f0-a438-11ee-88ec-eb6a8d5269b4
# 2      1683313906589747975   GEAR_DRIVE  af85a6f6-a433-11ee-88ec-eb6a8d5269b4
# 3      1683314881649993568   GEAR_DRIVE  28d53173-a437-11ee-88ec-eb6a8d5269b4
# 4      1683314760110715383   GEAR_DRIVE  beef3d58-a436-11ee-88ec-eb6a8d5269b4
# ...                    ...          ...                                   ...
# 55891  1692299145850170760   GEAR_DRIVE  37d6c8b4-db3f-11ee-a158-97f8443fd730
# 55892  1692298923496551489   GEAR_DRIVE  22545bdc-db3d-11ee-a158-97f8443fd730
# 55893  1692298588769229082   GEAR_DRIVE  61c69f67-db3a-11ee-a158-97f8443fd730
# 55894  1692298705562531654   GEAR_DRIVE  1cef0c3b-db3b-11ee-a158-97f8443fd730
# 55895  1692298334341250458   GEAR_DRIVE  68ee4c46-db38-11ee-a158-97f8443fd730
#
#        throttlePercentage  steeringPercentage  brakePercentage  ...  \
# 0                     0.0            0.667005             12.8  ...
# 1                     0.0           -0.185279              0.0  ...
# 2                     3.6            0.000000              0.0  ...
# 3                     6.4            3.909389              0.0  ...
# 4                    13.2           -0.111167              0.0  ...
# ...                   ...                 ...              ...  ...
# 55891                 0.0            0.127326             18.9  ...
# 55892                 9.0            0.009794              0.0  ...
# 55893                 0.0            1.400588             46.2  ...
# 55894                10.1           -0.146915              0.0  ...
# 55895                28.4            0.284035              0.0  ...
#
#                           groupMetadataID_y  longitude  solutionAge  \
# 0      2837eb9c-9542-11ee-956e-9da2d070324c -82.127928          0.0
# 1      2837eb9c-9542-11ee-956e-9da2d070324c -82.106265          0.0
# 2      2837eb9c-9542-11ee-956e-9da2d070324c -82.137651          0.0
# 3      2837eb9c-9542-11ee-956e-9da2d070324c -82.135521          0.0
# 4      2837eb9c-9542-11ee-956e-9da2d070324c -82.132322          0.0
# ...                                     ...        ...          ...
# 55891  dc39aa14-db32-11ee-a158-97f8443fd730 -82.129929          0.0
# 55892  dc39aa14-db32-11ee-a158-97f8443fd730 -82.142658          0.0
# 55893  dc39aa14-db32-11ee-a158-97f8443fd730 -82.136133          0.0
# 55894  dc39aa14-db32-11ee-a158-97f8443fd730 -82.143821          0.0
# 55895  dc39aa14-db32-11ee-a158-97f8443fd730 -82.136334          0.0
#
#           solStatus  msg_type_y numSatsInSolution  header.moduleName_y  \
# 0      SOL_COMPUTED         NaN                13                 gnss
# 1      SOL_COMPUTED         NaN                 8                 gnss
# 2      SOL_COMPUTED         NaN                 7                 gnss
# 3      SOL_COMPUTED         NaN                11                 gnss
# 4      SOL_COMPUTED         NaN                12                 gnss
# ...             ...         ...               ...                  ...
# 55891  SOL_COMPUTED         NaN                 7                 gnss
# 55892  SOL_COMPUTED         NaN                 5                 gnss
# 55893  SOL_COMPUTED         NaN                15                 gnss
# 55894  SOL_COMPUTED         NaN                11                 gnss
# 55895  SOL_COMPUTED         NaN                11                 gnss
#
#        header.sequenceNum_y header.timestampSec_y LatLonTotalStdDev
# 0                      1508          1.683315e+09          0.020301
# 1                      1822          1.683315e+09          0.050962
# 2                       455          1.683314e+09          0.051098
# 3                      1430          1.683315e+09          0.040241
# 4                      1308          1.683315e+09          0.024295
# ...                     ...                   ...               ...
# 55891                  1984          1.692299e+09          0.139507
# 55892                  1761          1.692299e+09          4.939038
# 55893                  1427          1.692299e+09          0.016303
# 55894                  1544          1.692299e+09          0.033331
# 55895                  1172          1.692298e+09          0.038149
#
# [2596405 rows x 66 columns]

# %%
cols_1 = [
"drivingMode",
"topic_x",
"time_x",
"throttlePercentage",
"steeringPercentage",
"brakePercentage",
"groupMetadataID_x",
"steeringRate",
"speedMps",
"signal.turnSignal",
"wheelSpeed.wheelSpdRr",
"wheelSpeed.wheelSpdFr",
"wheelSpeed.wheelSpdRl",
"wheelSpeed.wheelSpdFl",
"BinaryDrivingMode",
"TernaryDrivingModeTransition",
"ChassisBestPoseMatchedTime",
"topic_y",
"gpsGlonassUsedMask",
"time_y",
"longitudeStdDev",
"undulation",
"numSatsTracked",
"baseStationId",
"latitudeStdDev",
"differentialAge",
"solType",
"galileoBeidouUsedMask",
"latitude",
"numSatsL1",
"datumId",
"measurementTime",
"extendedSolutionStatus",
"heightStdDev",
"numSatsMulti",
"heightMsl",
"groupMetadataID_y",
"longitude",
"solutionAge",
"solStatus",
"numSatsInSolution",
"LatLonTotalStdDev"
]

blue_df = blue_df[cols_1]

# %%
blue_df = blue_df.sort_values(by='time_x')

# %%
blue_df.head()
# Out:
#            drivingMode                 topic_x               time_x  \
# 80880  COMPLETE_MANUAL  /apollo/canbus/chassis  1674155614234437896
# 11162  COMPLETE_MANUAL  /apollo/canbus/chassis  1674155614254411364
# 30728  COMPLETE_MANUAL  /apollo/canbus/chassis  1674155614277539249
# 28454  COMPLETE_MANUAL  /apollo/canbus/chassis  1674155614295697590
# 29500  COMPLETE_MANUAL  /apollo/canbus/chassis  1674155614315373681
#
#        throttlePercentage  steeringPercentage  brakePercentage  \
# 80880                 0.0           -93.10276              0.0
# 11162                 0.0           -93.10276              0.0
# 30728                 0.0           -93.13981              0.0
# 28454                 0.0           -93.13981              0.0
# 29500                 0.0           -93.13981              0.0
#
#                           groupMetadataID_x  steeringRate  speedMps  \
# 80880  3a116996-93a9-11ee-956e-9da2d070324c             0  1.343317
# 11162  3a116996-93a9-11ee-956e-9da2d070324c             0  1.343317
# 30728  3a116996-93a9-11ee-956e-9da2d070324c             0  1.358508
# 28454  3a116996-93a9-11ee-956e-9da2d070324c             0  1.358508
# 29500  3a116996-93a9-11ee-956e-9da2d070324c             0  1.358508
#
#       signal.turnSignal  ...  extendedSolutionStatus  heightStdDev  \
# 80880         TURN_NONE  ...                      33      0.041014
# 11162         TURN_NONE  ...                      33      0.041014
# 30728         TURN_NONE  ...                      33      0.041014
# 28454         TURN_NONE  ...                      33      0.041014
# 29500         TURN_NONE  ...                      33      0.041014
#
#        numSatsMulti   heightMsl                     groupMetadataID_y  \
# 80880            12  198.139637  3a116996-93a9-11ee-956e-9da2d070324c
# 11162            12  198.139637  3a116996-93a9-11ee-956e-9da2d070324c
# 30728            12  198.139637  3a116996-93a9-11ee-956e-9da2d070324c
# 28454            12  198.139637  3a116996-93a9-11ee-956e-9da2d070324c
# 29500            12  198.139637  3a116996-93a9-11ee-956e-9da2d070324c
#
#        longitude  solutionAge     solStatus  numSatsInSolution  \
# 80880 -82.105316          0.0  SOL_COMPUTED                 12
# 11162 -82.105316          0.0  SOL_COMPUTED                 12
# 30728 -82.105316          0.0  SOL_COMPUTED                 12
# 28454 -82.105316          0.0  SOL_COMPUTED                 12
# 29500 -82.105316          0.0  SOL_COMPUTED                 12
#
#        LatLonTotalStdDev
# 80880           0.014203
# 11162           0.014203
# 30728           0.014203
# 28454           0.014203
# 29500           0.014203
#
# [5 rows x 42 columns]

# %%
train_count = route_count //2


    
d_cols = [
#"drivingMode",
#"BinaryDrivingMode",
#"time",
"throttlePercentage",
"steeringPercentage",
"brakePercentage",
#"groupMetadataID",
"steeringRate",
"speedMps",
]

d2_cols = [
#"drivingMode",
#"topic_x",
#"time_x",
"throttlePercentage",
"steeringPercentage",
"brakePercentage",
#"groupMetadataID_x",
"steeringRate",
"speedMps",
#"signal.turnSignal",
#"wheelSpeed.wheelSpdRr",
#"wheelSpeed.wheelSpdFr",
#"wheelSpeed.wheelSpdRl",
#"wheelSpeed.wheelSpdFl",
#"BinaryDrivingMode",
#"TernaryDrivingModeTransition",
#"ChassisBestPoseMatchedTime",
#"topic_y",
#"gpsGlonassUsedMask",
#"time_y",
#"longitudeStdDev",
#"undulation",
#"numSatsTracked",
#"baseStationId",
#"latitudeStdDev",
"differentialAge",
#"solType",
#"galileoBeidouUsedMask",
#"latitude",
#"numSatsL1",
#"datumId",
#"measurementTime",
#"extendedSolutionStatus",
"heightStdDev",
#"numSatsMulti",
#"heightMsl",
#"groupMetadataID_y",
#"longitude",
#"solutionAge",
#"solStatus",
"numSatsInSolution",
"LatLonTotalStdDev"
]




r_cols = [
#"BinaryDrivingMode"
"TernaryDrivingModeTransition"
]

# %%
train_ids = blue_df["groupMetadataID_x"].unique()[:train_count]
test_ids = blue_df["groupMetadataID_x"].unique()[train_count:]

# %% [markdown]
# ## Decision Tree

# %%
from sklearn import tree
X_train = blue_df[ blue_df['groupMetadataID_x'].isin(train_ids)][d_cols]
Y_train = blue_df[ blue_df['groupMetadataID_x'].isin(train_ids)][r_cols]

X_test = blue_df[ blue_df['groupMetadataID_x'].isin(test_ids)][d_cols]
Y_test = blue_df[ blue_df['groupMetadataID_x'].isin(test_ids)][r_cols]


clf = tree.DecisionTreeClassifier(max_depth=5)
clf = clf.fit(X_train, Y_train)

# %%
prediction = clf.predict(X_test)
prediction
#blue_df[d_cols].iloc[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
results= pd.DataFrame()
results["predicted"] = prediction
results['actual'] = list(Y_test['TernaryDrivingModeTransition'])
results
# Out:
#          predicted  actual
# 0                0      -1
# 1                0      -1
# 2                0      -1
# 3                0      -1
# 4                0      -1
# ...            ...     ...
# 1570753          0      -1
# 1570754          0      -1
# 1570755          0      -1
# 1570756          0      -1
# 1570757          0      -1
#
# [1570758 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix

tn, fp, fn, tp = confusion_matrix(Y_test, prediction).ravel()

p = tp + fn
n = tn + fp


tpr = tp/p
tnr = tn/p

acccuracy = (tp+tn)/(tp+fp+tn+fn)
balanced_acccuracy = (tpr+tnr)/2


print(f"p: {p}")
print(f"n: {n}")
print(f"tp: {tp}")
print(f"fp: {fp}")
print(f"tn: {tn}")
print(f"fn: {fn}")

print(f"tpr: {tpr}")
print(f"tnr: {tnr}")


print(f'acccuracy: {acccuracy}')
print(f'balanced_acccuracy: {balanced_acccuracy}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 3
#       1 from sklearn.metrics import confusion_matrix
# ----> 3 tn, fp, fn, tp = confusion_matrix(Y_test, prediction).ravel()
#       5 p = tp + fn
#       6 n = tn + fp
#
# ValueError: too many values to unpack (expected 4)

# %%
from sklearn import tree
X_train = blue_df[ blue_df['groupMetadataID_x'].isin(train_ids)][d2_cols]
Y_train = blue_df[ blue_df['groupMetadataID_x'].isin(train_ids)][r_cols]

X_test = blue_df[ blue_df['groupMetadataID_x'].isin(test_ids)][d2_cols]
Y_test = blue_df[ blue_df['groupMetadataID_x'].isin(test_ids)][r_cols]


clf = tree.DecisionTreeClassifier(max_depth=5)
clf = clf.fit(X_train, Y_train)

# %%
prediction = clf.predict(X_test)
prediction
#blue_df[d_cols].iloc[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix

tn, fp, fn, tp = confusion_matrix(Y_test, prediction).ravel()

p = tp + fn
n = tn + fp


tpr = tp/p
tnr = tn/p

acccuracy = (tp+tn)/(tp+fp+tn+fn)
balanced_acccuracy = (tpr+tnr)/2


print(f"p: {p}")
print(f"n: {n}")
print(f"tp: {tp}")
print(f"fp: {fp}")
print(f"tn: {tn}")
print(f"fn: {fn}")

print(f"tpr: {tpr}")
print(f"tnr: {tnr}")


print(f'acccuracy: {acccuracy}')
print(f'balanced_acccuracy: {balanced_acccuracy}')
# Out:
# p: 1169218
# n: 401540
# tp: 816909
# fp: 110922
# tn: 290618
# fn: 352309
# tpr: 0.698679801371515
# tnr: 0.2485575829314978
# acccuracy: 0.7050907905609903
# balanced_acccuracy: 0.47361869215150637

# %%
#tree.plot_tree(clf)

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)

neigh.fit(X_train, Y_train)

#print(neigh.predict(X_test.iloc[0]))
#print(neigh.predict_proba([[0.9]]))
# Out:
# /home/vhepola_linux/do-env/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=3)

# %%
prediction = neigh.predict(X_test)  

tn, fp, fn, tp = confusion_matrix(Y_test, prediction).ravel()

print(f"tp: {tp}")
print(f"fp: {fp}")
print(f"tn: {tn}")
print(f"fn: {fn}")
# Out:
# tp: 805041
# fp: 136994
# tn: 264546
# fn: 364177

# %%
tpr = tp/p
tnr = tn/p

acccuracy = (tp+tn)/(tp+fp+tn+fn)
balanced_acccuracy = (tpr+tnr)/2


print(f"tpr: {tpr}")
print(f"tnr: {tnr}")


print(f'acccuracy: {acccuracy}')
print(f'balanced_acccuracy: {balanced_acccuracy}')
# Out:
# tpr: 0.6885294273608514
# tnr: 0.22625891835397677
# acccuracy: 0.6809368470509143
# balanced_acccuracy: 0.4573941728574141
