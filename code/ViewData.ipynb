# %% [markdown]
# # BOTO & PandasGUI
#
# ### **Goal:** Access dataset and metadata from DynamoDB. View both with PandasGUI

# %%
import boto3
import pandas as pd

from pandasgui import show

from boto3.dynamodb.conditions import Key, Attr

# %% [markdown]
# Connecting to the dataset

# %%
client = boto3.client('dynamodb')

dynamodb = boto3.resource('dynamodb')

mainTable = dynamodb.Table('ads_passenger_processed')
metaTable = dynamodb.Table('ads_passenger_processed_metadata')

# %% [markdown]
# Pull sample data using the scan command

# %%
mainResponse = mainTable.scan(FilterExpression=Attr('time').gt(0))
metaResponse = metaTable.scan(FilterExpression=Attr('time').gt(0))

print(dict.keys(mainResponse))
print(dict.keys(metaResponse))
# Out:
# dict_keys(['Items', 'Count', 'ScannedCount', 'LastEvaluatedKey', 'ResponseMetadata'])
# dict_keys(['Items', 'Count', 'ScannedCount', 'LastEvaluatedKey', 'ResponseMetadata'])

# %% [markdown]
# Coerce datasets into a pandas DataFrame

# %%
main_df = pd.DataFrame.from_dict(pd.json_normalize(
    mainResponse['Items']), orient='columns')
meta_df = pd.DataFrame.from_dict(pd.json_normalize(
    metaResponse['Items']), orient='columns')

# %%
main_df.head()
# Out:
#   yawRate          drivingMode                              topic msgsize  \
# 0       0  COMPLETE_AUTO_DRIVE             /apollo/canbus/chassis     133
# 1     NaN                  NaN       /apollo/sensor/gnss/odometry     109
# 2     NaN                  NaN                                /tf     103
# 3     NaN                  NaN    /apollo/localization/msf_status      69
# 4     NaN                  NaN  /apollo/sensor/gnss/corrected_imu     100
#
#                   time gearLocation                            metadataID  \
# 0  1701972580600806943   GEAR_DRIVE  e3362dcd-f0e0-11ee-ba1e-fb353e7798cd
# 1  1693325927615587598          NaN  4931fe4c-efa0-11ee-b966-fb353e7798cd
# 2  1704824442246497208          NaN  88c81562-f105-11ee-ba41-fb353e7798cd
# 3  1694623978391998055          NaN  644d56b6-c85a-11ee-a7fc-dd032dba19e8
# 4  1695151060395748558          NaN  9376f90f-eff0-11ee-b966-fb353e7798cd
#
#   throttlePercentage steeringPercentage brakePercentage  ... modules.Planning  \
# 0               11.6         0.74436826               0  ...              NaN
# 1                NaN                NaN             NaN  ...              NaN
# 2                NaN                NaN             NaN  ...              NaN
# 3                NaN                NaN             NaN  ...              NaN
# 4                NaN                NaN             NaN  ...              NaN
#
#   modules.Localization modules.Transform modules.Canbus  \
# 0                  NaN               NaN            NaN
# 1                  NaN               NaN            NaN
# 2                  NaN               NaN            NaN
# 3                  NaN               NaN            NaN
# 4                  NaN               NaN            NaN
#
#   monitoredComponents.Lidar.status monitoredComponents.ESD-CAN.message  \
# 0                              NaN                                 NaN
# 1                              NaN                                 NaN
# 2                              NaN                                 NaN
# 3                              NaN                                 NaN
# 4                              NaN                                 NaN
#
#   monitoredComponents.ESD-CAN.status monitoredComponents.GPS.message  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#   monitoredComponents.GPS.status monitoredComponents.Localization.status
# 0                            NaN                                     NaN
# 1                            NaN                                     NaN
# 2                            NaN                                     NaN
# 3                            NaN                                     NaN
# 4                            NaN                                     NaN
#
# [5 rows x 510 columns]

# %% [markdown]
# View dataframes with PandasGUI

# %%
show(main_df)
show(meta_df)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI
# /tmp/ipykernel_116504/251717770.py:1: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_116504/251717770.py:1: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_116504/251717770.py:1: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_116504/251717770.py:1: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_116504/251717770.py:1: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_116504/251717770.py:1: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI
# /tmp/ipykernel_116504/251717770.py:2: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_116504/251717770.py:2: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_116504/251717770.py:2: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_116504/251717770.py:2: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_116504/251717770.py:2: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /tmp/ipykernel_116504/251717770.py:2: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
