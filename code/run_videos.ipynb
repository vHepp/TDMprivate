# %%
import plotly.express as px
import pandas as pd
import numpy as np
import os

# %%
from boto3.dynamodb.conditions import Key, Attr
import boto3

dynamodb = boto3.resource('dynamodb')
# Instantiate a table resource object
table = dynamodb.Table('ads_passenger_processed')
table_meta = dynamodb.Table('ads_passenger_processed_metadata')

# %%
s3_resource = boto3.resource('s3')
s3_client = boto3.client('s3')
bucket = s3_resource.Bucket('dot-aws-driveohio-stage')
for my_bucket_object in bucket.objects.filter(Prefix="Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/"):
#for my_bucket_object in bucket.objects.filter(Prefix="Deployment_2_SEOhio/GreenRoute/TRCVan2"):
    
    print(my_bucket_object.key)
# Out:
# Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/
# Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/20230119141304.json
# Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/20230119141304.record.00000
# Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/20230119141304_metadataVid.avi
# Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/20230119141333.json
# Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/20230119141333.record.00000
# Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/20230119141333.record.00001
# Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/20230119141333.record.00002
# Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/20230119141333.record.00003
# Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/20230119141333.record.00004
# Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/20230119141333.record.00005
# Deployment_2_SEOhio/Blue Route/OU Pacifica/1674155613/20230119141333.record.00006
# ...

# %% [markdown]
# ### Download the chosen video

# %%
if not os.path.exists(f"./videos"):
        os.makedirs(f"./videos")

s3_client.download_file('dot-aws-driveohio-stage', 'Deployment_2_SEOhio/Blue Route/OU Pacifica/1706299233/20240126150033_metadataVid.avi', 'videos/20240126150033_metadataVid.avi')

#s3_client.download_file('dot-aws-driveohio-stage', 'Deployment_2_SEOhio/GreenRoute/TRCVan2/1701192784/20231128123411_metadataVidMatched.avi', '20231128123411_metadataVidMatched.avi')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 s3_client.download_file('dot-aws-driveohio-stage', 'Deployment_2_SEOhio/Blue Route/OU Pacifica/1706299233/20240126150033_metadataVid.avi', 'videos/20240126150033_metadataVid.avi')
#       3 #s3_client.download_file('dot-aws-driveohio-stage', 'Deployment_2_SEOhio/GreenRoute/TRCVan2/1701192784/20231128123411_metadataVidMatched.avi', '20231128123411_metadataVidMatched.avi')
#
# File ~/do-env/lib/python3.10/site-packages/boto3/s3/inject.py:192, in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     157 """Download an S3 object to a file.
#     158
#     159 Usage::
#    (...)
#     189     transfer.
#     190 """
#     191 with S3Transfer(self, Config) as transfer:
# --> 192     return transfer.download_file(
#     193         bucket=Bucket,
#     194         key=Key,
# ...
